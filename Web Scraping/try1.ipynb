# %%
from tabula import read_pdf
from tabulate import tabulate
import pandas as pd
##import camelot

# %%
df = read_pdf("daily_18-06-2020.pdf",multiple_tables=True,pages='1' )
df2 = df[0]
df2.fillna(0, inplace=True)#Make null values as zero
df2
# Out:
# Got stderr: Jun 19, 2020 11:35:20 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jun 19, 2020 11:35:20 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jun 19, 2020 11:35:23 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 187 fonts
#                       Item         Unnamed: 0           Pettah Unnamed: 1  \
# 0                        0              Range          Average   Change *
# 1                        0             18-Jun    18-Jun 17-Jun          0
# 2          Rice (Rs/50 kg)                  \                0          0
# 3                  Samba 1  4900.00 - 4900.00  4900.00 4900.00          0
# 4                  Samba 2  4750.00 - 4800.00  4783.33 4783.33          0
# ...

# %%
df2.to_csv('as.csv')

# %%
df
